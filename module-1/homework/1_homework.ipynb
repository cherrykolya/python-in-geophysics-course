# %% [markdown]
# ## Задача 1: Угадать число
#
# Напишите программу, которая:
# 1. Генерирует случайное число от 1 до 100 (используйте модуль `random`).
# 2. Просит пользователя угадать это число.
# 3. Подсказывает пользователю:
#    - Если введённое число меньше загаданного, выводит сообщение: "Загаданное число больше".
#    - Если больше, выводит: "Загаданное число меньше".
# 4. Завершается, когда пользователь угадывает число, и выводит сообщение: "Поздравляем, вы угадали!".
# 5. Реализуйте программу в виде функции

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задача 2: Two Sum
#
# Дана неупорядоченная коллекция чисел (список) и целое число `target`. Необходимо найти два числа в списке, сумма которых равна `target`. Возвратите индексы этих чисел в виде списка.
#
# **Условия:**
# - Вам нужно найти два числа, сумма которых равна `target`.
# - Возвращаемый список должен содержать индексы этих чисел (нумерация с 0).
# - Каждое число можно использовать только один раз.
# - Гарантируется, что решение существует.
#
# **Пример 1:**
# ```python
# nums = [2, 7, 11, 15]
# target = 9

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задача: Частотный словарь
#
# Напишите программу, которая:
# 1. Принимает на вход строку текста.
# 2. Создаёт словарь, где ключами являются уникальные символы строки, а значениями — количество их вхождений в строку.
# 3. Выводит частотный словарь.

# %%
# YOUR CODE HERE
