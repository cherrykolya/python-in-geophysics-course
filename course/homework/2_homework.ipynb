# %% [markdown]
# # Задача 1: Смоделировать работу пиццерии
#
# ## Условие
#
# Вам необходимо смоделировать работу пиццерии, используя объектно-ориентированное программирование (ООП). Реализуйте следующие классы:
#
# ### 1. `Pizzeria`
# - Отвечает за управление очередью клиентов и процессом приготовления.
# - Работает в **бесконечном цикле** (можно ограничить число итераций для тестирования).
# - В каждой итерации:
#   - С вероятностью 50% в очередь добавляется новый заказ.
#   - Если в очереди есть заказы, передает заказ на приготовление повару.
#   - Повар готовит заказ, после чего заказ удаляется из очереди.
#
# ### 2. `Order`
# - Хранит информацию о заказе, например:
#   - Имя клиента.
#   - Вид пиццы из доступных (`"Маргарита"`, `"Пепперони"`, `"Вегетарианская"`, `"Четыре сыра"`).
# - Заказ клиента формируется случайным образом при его создании.
#
# ### 3. `Chef`
# - Отвечает за приготовление заказов.
# - Готовит одну пиццу за одну итерацию, выводя в консоль сообщение: `"Готовится пицца <название> для клиента <имя>"`.
# - После приготовления заказа повар завершает работу над ним.
#
# ## Дополнительно:
# - Добавьте возможность завершения работы пиццерии после обработки фиксированного числа итераций (например, 10).
# - Выводите в консоль на каждом шаге:
#   - Состояние очереди клиентов.
#   - Статус приготовления.

# %%
# YOUR CODE HERE

# %% [markdown]
# # Задача 2: Работа с большими файлами через генераторы и итераторы (с измерением потребляемой памяти)
#
# ## Условие
#
# Вам нужно реализовать два варианта обработки больших текстовых файлов с использованием:
# 1. **Генератора**.
# 2. **Итератора**.
#
# Каждый файл содержит большое количество строк, и ваша задача — считать файл по одной строке, обработать её и вывести в консоль обработанную строку. При этом необходимо измерить и сравнить потребляемую память для каждого из вариантов.
#
# ### Требования:
# 1. **Файл для тестирования**:
#    - Создайте текстовый файл `large_file.txt` размером не менее 100 МБ, где каждая строка состоит из случайного набора слов.
#    - Пример строки: `"word1 word2 word3 word4 word5"`.
#
# 2. **Реализация через генератор**:
#    - Напишите функцию-генератор `file_reader_generator`, которая открывает файл, считывает строки по одной и возвращает их.
#
# 3. **Реализация через итератор**:
#    - Создайте класс `FileReaderIterator`, который реализует методы `__iter__` и `__next__`. Этот класс должен обеспечивать итерацию по строкам файла.
#
# 4. Обработка строки:
#    - Для каждой строки выполните следующую обработку:
#      - Преобразуйте все слова в строке в верхний регистр.
#      - Подсчитайте количество слов в строке.
#    - Выведите в консоль обработанную строку и количество слов в ней.
#
# 5. **Измерение памяти**:
#    - Используйте библиотеку `psutil` или `memory_profiler` для измерения потребляемой памяти. Сравните, сколько памяти занимает выполнение программы для генератора и для итератора.
#    - Выведите потребляемую память до и после выполнения чтения файла и обработки каждой строки.
#
# 6. **Сравнение**:
#    - После выполнения обработки с каждым подходом выведите, сколько памяти потребляет каждый вариант обработки.

# %%
# YOUR CODE HERE
