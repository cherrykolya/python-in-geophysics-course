# %% [markdown]
# ## Задача 1: Рефакторинг кода из лекции
#
# ## Условие:
# Перепишите существующий код из лекции, разделив его на четыре основные функции:
#
# 1. **Чтение данных:**
# 2. **Визуализация данных:**
# 3. **Обработка данных:**
# 4. **Моделирование данных:**
#
# ## Результат:
# - Разделите функциональность кода по этим функциям.
# - Напишите основной блок, который вызывает функции последовательно, передавая данные между ними.
# - Старайтесь соответствовать принцпиам SOLID при написании кода

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задача 2: Вычисление атрибута когерентности и сохранение в новый SEG-Y файл
#
# ## Условие:
# 1. **Чтение данных:**
# 2. **Расчет атрибута когерентности:**
# 3. **Запись данных:**
#
# ## Результат:
# - Основной блок кода должен:
#   1. Читать SEG-Y файл.
#   2. Рассчитывать атрибут когерентности.
#   3. Сохранять результаты в новый SEG-Y файл.
#
# ## Дополнительно:
# - Визуализируйте оригинальные данные и данные когерентности для проверки качества результата. Используйте Matplotlib или другую библиотеку визуализации.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задача 3: Усложненное моделирование годографов для многослойной среды
#
# ## Условие:
# 1. **Цель задачи:**
#    - Моделировать годографы для среды, содержащей \( n \) слоев.
#    - Учитывать прямую волну, однократно и кратно отраженные волны.
#    - Использовать одномерную модель: скорость в каждом слое постоянна, среда изотропна.
#
# 2. **Задачи:**
#    - **Определение параметров среды:**
#    - **Расчет времени пробега:**
#    - **Моделирование годографов:**
#    - **Визуализация:**
#
# 3. **Результат:**
#    - Смоделируйте годографы для среды с несколькими слоями (например, 3–5 слоев).
#    - Убедитесь, что каждая волна (прямая, однократно отраженная, кратно отраженная) визуализирована отдельно и подписана.

# %%
# YOUR CODE HERE
